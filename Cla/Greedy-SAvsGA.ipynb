# %%
from itertools import combinations

import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import random
import math

from icecream import ic

# %% [markdown]
# Cost: $d + (d \cdot \alpha \cdot w)^\beta$ with $\alpha \ge 0$ and $\beta \ge 0$

# %%
class Problem:
    _graph: nx.Graph
    _alpha: float
    _beta: float

    def __init__(
        self,
        num_cities: int,
        *,
        alpha: float = 1.0,
        beta: float = 1.0,
        density: float = 0.5,
        seed: int = 42,
    ):
        rng = np.random.default_rng(seed)
        self._alpha = alpha
        self._beta = beta
        cities = rng.random(size=(num_cities, 2))
        cities[0, 0] = cities[0, 1] = 0.5

        self._graph = nx.Graph()
        self._graph.add_node(0, pos=(cities[0, 0], cities[0, 1]), gold=0)
        for c in range(1, num_cities):
            self._graph.add_node(c, pos=(cities[c, 0], cities[c, 1]), gold=(1 + 999 * rng.random()))

        tmp = cities[:, np.newaxis, :] - cities[np.newaxis, :, :]
        d = np.sqrt(np.sum(np.square(tmp), axis=-1))
        for c1, c2 in combinations(range(num_cities), 2):
            if rng.random() < density or c2 == c1 + 1:
                self._graph.add_edge(c1, c2, dist=d[c1, c2])

        assert nx.is_connected(self._graph)

    @property
    def graph(self) -> nx.Graph:
        return nx.Graph(self._graph)

    @property
    def alpha(self):
        return self._alpha

    @property
    def beta(self):
        return self._beta

    def cost(self, path, weight):
        dist = nx.path_weight(self._graph, path, weight='dist')
        return dist + (self._alpha * dist * weight) ** self._beta

    def baseline(self):
        total_cost = 0
        for dest, path in nx.single_source_dijkstra_path(
            self._graph, source=0, weight='dist'
        ).items():
            cost = 0
            for c1, c2 in zip(path, path[1:]):
                cost += self.cost([c1, c2], 0)
                cost += self.cost([c1, c2], self._graph.nodes[dest]['gold'])
            logging.debug(
                f"dummy_solution: go to {dest} ({' > '.join(str(n) for n in path)} ({cost})"
            )
            total_cost += cost
        return total_cost

    def plot(self):
        plt.figure(figsize=(10, 10))
        pos = nx.get_node_attributes(self._graph, 'pos')
        size = [100] + [self._graph.nodes[n]['gold'] for n in range(1, len(self._graph))]
        color = ['red'] + ['lightblue'] * (len(self._graph) - 1)
        return nx.draw(self._graph, pos, with_labels=True, node_color=color, node_size=size)

# %%
def precompute_distances(problem):
    """
    Calcola matrice delle distanze tra tutte le coppie di nodi nel grafo del problema.
    Restituisce una matrice 2D numpy NxN dove l'elemento (i, j) rappresenta la distanza tra il nodo i e il nodo j.
    """
    graph = problem._graph
    n = len(graph.nodes)
    #print("Pre-calcolo delle distanze in corso...")
    # Inizializza una matrice NxN con tutti zeri
    dist_matrix = np.zeros((n, n))

    all_pairs = nx.all_pairs_dijkstra_path_length(graph, weight='dist')
    # Popola la matrice delle distanze
    for src, targets in all_pairs:
        for tgt, d in targets.items():
            dist_matrix[src][tgt] = d
    #print("Pre-calcolo delle distanze completato.")
    return dist_matrix

# %%
# ---- FUNZIONI DI SUPPORTO ----
def getCost(problem, solution, dist_matrix):
    """Calcola il costo (Energia) della soluzione."""
    cost = 0
    weight = 0
    current = 0
    alpha = problem._alpha
    beta = problem._beta

    for node in solution:
        if node == 0:
            if current != 0:
                d = dist_matrix[current][0]
                cost += d + (alpha * d * weight) ** beta
                weight = 0
                current = 0
        else:
            d = dist_matrix[current][node]
            cost += d + (alpha * d * weight) ** beta
            weight += problem._graph.nodes[node]['gold']
            current = node

    if current != 0:
        d = dist_matrix[current][0]
        cost += d + (alpha * d * weight) ** beta

    return cost

# %%
def two_opt_segment(path, i, j):
    new_path = list(path)
    new_path[i:j] = reversed(new_path[i:j])
    return new_path


def insert_return(path):
    new = list(path)
    pos = random.randint(1, len(new))
    if new[pos - 1] != 0:
        new.insert(pos, 0)
    return new


def remove_return(path):
    new = list(path)
    zeros = [i for i, v in enumerate(new) if v == 0]
    if zeros:
        new.pop(random.choice(zeros))
    return new

# %% [markdown]
# # Thermodynamic Greedy Search + SA

# %%
class ThermodynamicGreedySearch:
    def __init__(self, problem, dist_matrix,
                 initial_temp=2000.0,
                 cooling_rate=0.995,
                 min_temp=0.1,
                 iter_per_temp=50):

        self.problem = problem
        self.dist_matrix = dist_matrix
        self.n_cities = len(problem._graph.nodes)

        # parametri fisici
        self.T = initial_temp
        self.cooling_rate = cooling_rate
        self.min_temp = min_temp
        self.iter_per_temp = iter_per_temp

    def run(self):
        #print("--- Inizio Thermodynamic Greedy Search ---")

        # 1. GENERAZIONE SOLUZIONE INIZIALE (La Regola Aurea)
        # Costruiamo una soluzione greedy intelligente basata sul "Peso Futuro"
        current_solution = self._generate_golden_greedy()
        current_energy = getCost(self.problem, current_solution, self.dist_matrix)

        best_solution = list(current_solution)
        best_energy = current_energy
        #print(f"Energia Iniziale (Greedy): {best_energy:.2f}")
        
        # 2. CICLO PRINCIPALE DEL SIMULATED ANNEALING
        iteration = 0
        while self.T > self.min_temp:
            for _ in range(self.iter_per_temp):
                # a. perturbazione casuale della soluzione corrente
                move = random.choice(["2opt", "add0", "rem0"])

                if move == "2opt" and len(current_solution) >= 2:
                    i, j = sorted(random.sample(range(len(current_solution)), 2))
                    candidate = two_opt_segment(current_solution, i, j)
                elif move == "add0":
                    candidate = insert_return(current_solution)
                else:
                    candidate = remove_return(current_solution)
                
                # b. CALCOLO ENERGIA CANDIDATO
                candidate_energy = getCost(
                    self.problem, candidate, self.dist_matrix
                )

                delta = candidate_energy - current_energy

                # c. Legge di Boltzmann
                # Accettiamo se migliora (delta < 0) OPPURE se il dado di Boltzmann dice sì
                if delta < 0 or random.random() < math.exp(-delta / self.T):
                    current_solution = candidate
                    current_energy = candidate_energy
                    # Aggiorniamo il record assoluto
                    if current_energy < best_energy:
                        best_energy = current_energy
                        best_solution = list(current_solution)

            self.T *= self.cooling_rate
            iteration += 1
            if iteration % 50 == 0:
                print(f"Temp: {self.T:.2f} | Energia: {current_energy:.2f} | Record: {best_energy:.2f}")

        return best_solution, best_energy

    def _generate_initial_solution(self):
        nodes = list(range(1, self.n_cities))
        random.shuffle(nodes)
        return nodes

    def _generate_golden_greedy(self):
        """
        Genera la soluzione iniziale usando la 'Regola Aurea':
        Preferisci città vicine MA penalizza quelle pesanti se sei lontano da casa.
        """
        unvisited = set(range(1, self.n_cities))
        curr = 0
        path = []
        
        # Estraiamo i pesi (oro)
        gold = {i: self.problem._graph.nodes[i].get('gold', 0) for i in range(self.n_cities)}
        
        while unvisited:
            best_next = -1
            best_score = float('inf')
            
            for city in unvisited:
                dist = self.dist_matrix[curr][city]
                weight = gold[city]
                dist_to_home = self.dist_matrix[city][0]
                
                # FORMULA AUREA:
                # Score = Distanza * (1 + FattorePeso)
                # Il FattorePeso cresce se la città è pesante E lontana da casa
                weight_penalty = (weight * dist_to_home) / 1000.0 # Normalizzazione euristica
                
                score = dist + weight_penalty
                
                if score < best_score:
                    best_score = score
                    best_next = city
            
            path.append(best_next)
            unvisited.remove(best_next)
            curr = best_next
            
        return path

# %% [markdown]
# problem_instance = Problem(100, density=0.2, alpha=1, beta=1)
# dist_matrix = precompute_distances(problem_instance)
# problem_instance.plot()
#
# solver = ThermodynamicGreedySearch(
#     problem_instance,
#     dist_matrix,
#     initial_temp=20000.0,
#     cooling_rate=0.995,
#     min_temp=0.1,
#     iter_per_temp=50
# )
#
# sol, cost = solver.run()
# improvement = 100 * (problem_instance.baseline() - cost) / problem_instance.baseline()
#
# print(f"\nCosto finale: {cost:.2f}")
# print(f"Baseline: {problem_instance.baseline():.2f}")
# print(f"Miglioramento: {improvement:.2f}%")

# %% [markdown]
# # ALGORITMI GENETICI (GA)

# %%
def getFastSmartCost(problem: Problem, solution: list[int], dist_matrix) -> float:
    """
    For each step, calculate the cost considering the accumulated weight using the precomputed distance matrix.
    """
    cost = 0
    weight = 0
    current_node = 0  # start from the node 0

    alpha = problem._alpha
    beta = problem._beta

    # Visit each city in the solution path
    for next_node in solution:
        # get distance from precomputed matrix
        dist_direct = dist_matrix[current_node][next_node]
        dist_to_0 = dist_matrix[current_node][0]
        dist_from_0 = dist_matrix[0][next_node]
        
        # Aggiorniamo il costo 
        cost_direct = dist_direct + (alpha * dist_direct * weight) ** beta

        cost_via_0 = dist_to_0 + (alpha * dist_to_0 * weight) ** beta + dist_from_0
        if cost_via_0 < cost_direct:
            cost += cost_via_0
            weight = 0
        else:
            cost += cost_direct
        
        weight += problem._graph.nodes[next_node].get('gold',1)
        current_node = next_node

    dist_final = dist_matrix[current_node][0]
    cost += dist_final + (alpha * dist_final * weight) ** beta

    return cost

# %%
def tweak(solution: list[int]) -> list[int]:
    """
    Applia un piccolo cambiamento (tweak) alla soluzione esistente
    scambiando due città nella lista.
    """
    if len(solution) < 2:
        return solution.copy()
    
    new_solution = solution.copy()
    i, j = random.sample(range(len(solution)), 2)
    new_solution[i], new_solution[j] = new_solution[j], new_solution[i]
    return new_solution

# %% [markdown]
# population

# %%
POPULATION_SIZE = 100

def init_population(problem: Problem, population_size: int) -> list[list[int]]:
    """
    Inizializza una popolazione di soluzioni casuali.
    Ogni soluzione è una permutazione casuale delle città (escluso il deposito 0).
    """
    num_cities = len(problem._graph.nodes)
    cities = list(range(1, num_cities))  # Escludo il deposito 0

    population = []
    for _ in range(population_size):
        individual = cities.copy()
        random.shuffle(individual)
        population.append(individual)
    return population

# %% [markdown]
# Parent Selection: Tournament Selection

# %%
def tournament_selection(problem: Problem, population: list[list[int]], distance_matrix, tournament_size: int = 3):
    # Seleziono k individui casuali dalla popolazione
    candidates = random.sample(population, tournament_size)

    # Valuto chi tra loro a il costo migliore (minore)
    best_candidate = None
    best_cost = float('inf')

    for cand in candidates:
        cost = getFastSmartCost(problem, cand, distance_matrix)
        if cost < best_cost:
            best_cost = cost
            best_candidate = cand
    return best_candidate

# %% [markdown]
# ## Crossover - Order Crossover (OX)
#
# OX necessario al fine di non avere città duplicate negli individui figli

# %%
def crossover(parent1: list[int], parent2: list[int]) -> list[int]:
    """
    Applica l'operatore di crossover Order Crossover (OX) per generare un figlio
    da due genitori.
    """
    size = len(parent1)

    # Scelgo due punti di taglio casuali
    start, end = sorted(random.sample(range(size), 2))

    # Creo il figlio con None e copiamo la parte centrale da parent1
    child = [None] * size
    child[start:end+1] = parent1[start:end+1] # serve "+1" per includere end

    # Riempio il resto del figlio con gli elementi di parent2 nell'ordine in cui appaiono
    # Lo faccio scorrendo il genitore2 e prendendo solo gli elementi non ancora presenti nel figlio
    p2_genes = [gene for gene in parent2 if gene not in child[start:end+1]]

    current_p2_index = 0
    for i in range(size):
        if child[i] is None:
            child[i] = p2_genes[current_p2_index]
            current_p2_index += 1
    return child

# %% [markdown]
# ## Mutation

# %%
MUTATION_RATE = 0.2

def mutation(individual: list[int], mutation_rate: float=0.1) -> list[int]:
    """
    Applica la mutazione alla soluzione scambiando due città con una certa probabilità.
    """
    if random.random() < mutation_rate:
        return tweak(individual)
    else:
        return individual

# %% [markdown]
# ## Genetic Algorithm

# %%
NUM_GENERATIONS = 2_000

# %%
def genetic_algorithm(problem: Problem, distance_matrix, population_size: int = 50, generations: int = 1000, mutation_rate: float= 0.1):
    # Inizializzo la popolazione
    population = init_population(problem, population_size)

    best_solution = None
    best_cost = float('inf')

    #print(f"Inizio Genetic Algorithm con population_size={population_size}, generations={generations}, mutation_rate={mutation_rate}")

    for gen in range(generations):
        new_population = []

        # --- ELITISMO ---
        # Salviamo subito il migliore della vecchia generazione nella nuova popolazione
        # Questo garantisce che la qualità non peggiori
        population.sort(key=lambda x: getFastSmartCost(problem, x, distance_matrix))
        best_of_gen = population[0]
        cost_of_gen = getFastSmartCost(problem, best_of_gen, distance_matrix)

        if cost_of_gen < best_cost:
            best_cost = cost_of_gen
            best_solution = best_of_gen.copy()
            #print(f"Generation {gen}: Nuovo Record {best_cost:.2f}")

        new_population.append(best_of_gen)
        # -----------------

        # Riempiamo il resto della nuova popolazione (population_size - 1)
        while len(new_population) < population_size:
            # Parent Selection
            parent1 = tournament_selection(problem, population, distance_matrix)
            parent2 = tournament_selection(problem, population, distance_matrix)

            # Crossover
            child = crossover(parent1, parent2)

            # Mutation
            child = mutation(child, mutation_rate)

            new_population.append(child)
    
        # Sostituiamo la vecchia popolazione con la nuova
        population = new_population

    return best_solution, best_cost

# %%
POPULATION_SIZE = 50
MUTATION_RATE = 0.2
NUM_GENERATIONS = 2_000

# %% [markdown]
# # MAIN
# problem_instance = Problem(100, density=0.2, alpha=1, beta=1)
#
# # Pre-calcolo delle distanze
# dist_matrix = precompute_distances(problem_instance)
#
# sol, cost = genetic_algorithm(problem_instance, distance_matrix=dist_matrix, population_size=POPULATION_SIZE, generations=NUM_GENERATIONS, mutation_rate=MUTATION_RATE)
#
# print(f"\n---RISULTATO FINALE---")
# print(f"Costo Migliore: {cost:.2f}")
# print(f"Baseline (Dijkstra): {problem_instance.baseline():.2f}")
#
# # Controllo se ho battuto la baseline
# if cost < problem_instance.baseline():
#     print("VITTORIA: GA con distance matrix ha battuto la baseline!")
# else:
#     print("SCONFITTA: GA con distance matrix non è bastato (prova più iterazioni).")

# %%
import pandas as pd
import time

def run_comparison():
   # 1. Configurazione dei Test
    test_cases = [
    # (N, Density, Alpha, Beta)
    # Casi 100 Città
    (100, 0.2, 1, 1),
    (100, 0.2, 2, 1),
    (100, 0.2, 1, 2), # Attenzione: Beta=2 fa esplodere i costi!
    (100, 1.0, 1, 1),
    (100, 1.0, 2, 1),
    (100, 1.0, 1, 2),
    
    # Casi 1000 Città (Attenzione ai tempi!)
    # Per il test rapido, magari commenta questi e provali in un secondo momento
    # (1000, 0.2, 1, 1), 
    # (1000, 1.0, 1, 1),
]
    results = []
    print(f"{'SCENARIO':<30} | {'BASELINE':<12} | {'GA':<12} | {'SA':<12} | {'WINNER':<10}")
    print("-" * 90)
  

    for n_cities, dens, alpha, beta in test_cases:
        # a. SETUP PROBLEMA
        problem_instance = Problem(n_cities, density=dens, alpha=alpha, beta=beta)
                for beta in BETAS:

                    experiment_id += 1
                    print("\n" + "=" * 80)
                    print(f"Esperimento {experiment_id}")
                    print(f"n={n}, density={density}, alpha={alpha}, beta={beta}")
                    print("=" * 80)

                    # =========================
                    # CREAZIONE PROBLEMA
                    # =========================
                    problem_instance = Problem(
                        n,
                        density=density,
                        alpha=alpha,
                        beta=beta
                    )

                    # =========================
                    # BASELINE
                    # =========================
                    start = time.time()
                    baseline_cost = problem_instance.baseline()
                    baseline_time = time.time() - start

                    print(f"Baseline cost: {baseline_cost:.2f} ({baseline_time:.2f}s)")

                    # =========================
                    # PRECOMPUTE DISTANCES
                    # =========================
                    dist_matrix = precompute_distances(problem_instance)

                    # =========================
                    # ALGORITMO 1: GENETIC
                    # =========================
                    start = time.time()
                    sol_ga, cost_ga = genetic_algorithm(
                        problem_instance,
                        distance_matrix=dist_matrix,
                        population_size=POPULATION_SIZE,
                        generations=NUM_GENERATIONS,
                        mutation_rate=MUTATION_RATE
                    )
                    ga_time = time.time() - start

                    ga_improvement = 100 * (baseline_cost - cost_ga) / baseline_cost

                    print(
                        f"GA cost: {cost_ga:.2f} "
                        f"| Improvement: {ga_improvement:.2f}% "
                        f"| Time: {ga_time:.2f}s"
                    )

                    # =========================
                    # ALGORITMO 2: SA
                    # =========================
                    solver = ThermodynamicGreedySearch(
                        problem=problem_instance,
                        dist_matrix=dist_matrix,
                        initial_temp=2000.0,
                        cooling_rate=0.995,
                        min_temp=0.1,
                        iter_per_temp=50
                    )



                    start = time.time()
                    sol_sa, cost_sa = solver.run()
                    sa_time = time.time() - start

                    sa_improvement = 100 * (baseline_cost - cost_sa) / baseline_cost

                    print(
                        f"SA cost: {cost_sa:.2f} "
                        f"| Improvement: {sa_improvement:.2f}% "
                        f"| Time: {sa_time:.2f}s"
                    )

                    # =========================
                    # SALVATAGGIO RISULTATI
                    # =========================
                    results.append({
                        "n": n,
                        "density": density,
                        "alpha": alpha,
                        "beta": beta,
                        "baseline_cost": baseline_cost,
                        "baseline_time": baseline_time,
                        "ga_cost": cost_ga,
                        "ga_time": ga_time,
                        "ga_improvement_%": ga_improvement,
                        "sa_cost": cost_sa,
                        "sa_time": sa_time,
                        "sa_improvement_%": sa_improvement,
                    })

    # =========================
    # TABELLA FINALE
    # =========================
    df = pd.DataFrame(results)

    print("\n" + "=" * 80)
    print("RISULTATI FINALI")
    print("=" * 80)
    print(df)

    return df

# %%
df_results = run_comparison()
# Out:
# ================================================================================
# Esperimento 1
# n=50, density=0.2, alpha=0.5, beta=1.0
# ================================================================================
# Baseline cost: 6475.52 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 7070.02
# Generation 1: Nuovo Record 6859.74
# Generation 3: Nuovo Record 6812.73
# Generation 4: Nuovo Record 6780.28
# Generation 5: Nuovo Record 6727.99
# Generation 6: Nuovo Record 6594.03
# Generation 8: Nuovo Record 6534.47
# Generation 11: Nuovo Record 6531.81
# Generation 12: Nuovo Record 6523.83
# Generation 13: Nuovo Record 6505.96
# Generation 14: Nuovo Record 6495.43
# Generation 15: Nuovo Record 6474.15
# Generation 19: Nuovo Record 6474.11
# Generation 22: Nuovo Record 6473.45
# Generation 25: Nuovo Record 6473.33
# Generation 28: Nuovo Record 6473.33
# Generation 31: Nuovo Record 6473.16
# Generation 34: Nuovo Record 6472.62
# Generation 36: Nuovo Record 6472.23
# Generation 50: Nuovo Record 6472.23
# Generation 60: Nuovo Record 6471.66
# Generation 75: Nuovo Record 6471.66
# Generation 78: Nuovo Record 6470.99
# Generation 79: Nuovo Record 6470.97
# Generation 80: Nuovo Record 6470.29
# Generation 133: Nuovo Record 6469.75
# Generation 137: Nuovo Record 6469.75
# Generation 139: Nuovo Record 6468.57
# GA cost: 6468.57 | Improvement: 0.11% | Time: 3.22s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 136256.94
# Temp: 1556.63 | Energia: 13259.14 | Record: 10631.31
# Temp: 1211.54 | Energia: 12665.26 | Record: 10054.71
# Temp: 942.96 | Energia: 14821.04 | Record: 9896.47
# Temp: 733.92 | Energia: 13433.10 | Record: 8914.33
# Temp: 571.22 | Energia: 11673.53 | Record: 8914.33
# Temp: 444.58 | Energia: 9455.68 | Record: 8161.03
# Temp: 346.03 | Energia: 9986.55 | Record: 8010.16
# Temp: 269.32 | Energia: 10352.70 | Record: 7829.79
# Temp: 209.61 | Energia: 10115.57 | Record: 7829.79
# Temp: 163.14 | Energia: 8532.81 | Record: 7484.87
# Temp: 126.98 | Energia: 7498.61 | Record: 7009.13
# Temp: 98.83 | Energia: 7651.18 | Record: 6743.06
# Temp: 76.92 | Energia: 7201.27 | Record: 6738.48
# Temp: 59.87 | Energia: 6834.94 | Record: 6617.58
# Temp: 46.60 | Energia: 6904.61 | Record: 6617.58
# Temp: 36.27 | Energia: 7010.74 | Record: 6543.84
# Temp: 28.23 | Energia: 6633.49 | Record: 6514.54
# Temp: 21.97 | Energia: 6552.51 | Record: 6514.54
# Temp: 17.10 | Energia: 6494.15 | Record: 6475.26
# Temp: 13.31 | Energia: 6483.95 | Record: 6475.26
# Temp: 10.36 | Energia: 6474.88 | Record: 6471.13
# Temp: 8.06 | Energia: 6478.45 | Record: 6471.13
# Temp: 6.27 | Energia: 6473.74 | Record: 6471.13
# Temp: 4.88 | Energia: 6494.40 | Record: 6471.13
# Temp: 3.80 | Energia: 6474.15 | Record: 6471.13
# Temp: 2.96 | Energia: 6474.37 | Record: 6471.13
# Temp: 2.30 | Energia: 6476.14 | Record: 6471.13
# Temp: 1.79 | Energia: 6474.55 | Record: 6471.13
# Temp: 1.39 | Energia: 6475.44 | Record: 6471.13
# Temp: 1.09 | Energia: 6474.01 | Record: 6471.13
# Temp: 0.84 | Energia: 6474.27 | Record: 6471.13
# Temp: 0.66 | Energia: 6472.49 | Record: 6471.13
# Temp: 0.51 | Energia: 6473.90 | Record: 6471.13
# Temp: 0.40 | Energia: 6473.23 | Record: 6471.13
# Temp: 0.31 | Energia: 6474.28 | Record: 6471.13
# Temp: 0.24 | Energia: 6472.95 | Record: 6471.13
# Temp: 0.19 | Energia: 6471.50 | Record: 6471.13
# Temp: 0.15 | Energia: 6470.44 | Record: 6470.44
# Temp: 0.11 | Energia: 6468.62 | Record: 6468.62
# SA cost: 6468.62 | Improvement: 0.11% | Time: 3.72s
#
# ================================================================================
# Esperimento 2
# n=50, density=0.2, alpha=0.5, beta=2.0
# ================================================================================
# Baseline cost: 655973.24 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 1429988.59
# Generation 3: Nuovo Record 1336630.97
# Generation 4: Nuovo Record 1302488.92
# Generation 5: Nuovo Record 1243401.91
# Generation 6: Nuovo Record 1238182.47
# Generation 8: Nuovo Record 1236387.17
# Generation 9: Nuovo Record 1223875.21
# Generation 10: Nuovo Record 1214633.99
# Generation 11: Nuovo Record 1202155.64
# Generation 12: Nuovo Record 1197933.34
# Generation 13: Nuovo Record 1195103.33
# Generation 14: Nuovo Record 1136516.85
# Generation 15: Nuovo Record 1113751.18
# Generation 17: Nuovo Record 1109503.02
# Generation 18: Nuovo Record 1107584.38
# Generation 20: Nuovo Record 1104812.32
# Generation 21: Nuovo Record 1090859.92
# Generation 22: Nuovo Record 1088539.47
# Generation 23: Nuovo Record 1081921.05
# Generation 24: Nuovo Record 1074370.67
# Generation 26: Nuovo Record 1074328.28
# Generation 29: Nuovo Record 1072976.91
# Generation 32: Nuovo Record 1072189.87
# Generation 33: Nuovo Record 1072189.87
# Generation 66: Nuovo Record 1072189.87
# Generation 135: Nuovo Record 1063611.59
# Generation 148: Nuovo Record 1063611.59
# GA cost: 1063611.59 | Improvement: -62.14% | Time: 3.12s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 1025379265.20
# Temp: 1556.63 | Energia: 1141264.30 | Record: 1137298.82
# Temp: 1211.54 | Energia: 1129995.61 | Record: 1128347.25
# Temp: 942.96 | Energia: 1128347.25 | Record: 1127337.07
# Temp: 733.92 | Energia: 1112579.36 | Record: 1112579.36
# Temp: 571.22 | Energia: 1112181.55 | Record: 1112181.55
# Temp: 444.58 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 346.03 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 269.32 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 209.61 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 163.14 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 126.98 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 98.83 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 76.92 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 59.87 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 46.60 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 36.27 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 28.23 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 21.97 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 17.10 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 13.31 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 10.36 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 8.06 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 6.27 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 4.88 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 3.80 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 2.96 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 2.30 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 1.79 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 1.39 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 1.09 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 0.84 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 0.66 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 0.51 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 0.40 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 0.31 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 0.24 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 0.19 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 0.15 | Energia: 1103695.64 | Record: 1103695.64
# Temp: 0.11 | Energia: 1103695.64 | Record: 1103695.64
# SA cost: 1103695.64 | Improvement: -68.25% | Time: 3.58s
#
# ================================================================================
# Esperimento 3
# n=50, density=0.2, alpha=1.0, beta=1.0
# ================================================================================
# Baseline cost: 12897.33 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 14403.48
# Generation 1: Nuovo Record 13743.69
# Generation 2: Nuovo Record 13118.89
# Generation 7: Nuovo Record 13059.95
# Generation 9: Nuovo Record 13055.33
# Generation 10: Nuovo Record 12973.96
# Generation 12: Nuovo Record 12921.96
# Generation 14: Nuovo Record 12909.65
# Generation 15: Nuovo Record 12896.62
# Generation 17: Nuovo Record 12896.62
# Generation 20: Nuovo Record 12896.62
# Generation 22: Nuovo Record 12896.62
# Generation 23: Nuovo Record 12895.94
# Generation 24: Nuovo Record 12895.94
# Generation 26: Nuovo Record 12895.94
# Generation 27: Nuovo Record 12895.68
# Generation 28: Nuovo Record 12895.68
# Generation 29: Nuovo Record 12895.21
# Generation 32: Nuovo Record 12895.21
# Generation 34: Nuovo Record 12895.21
# Generation 37: Nuovo Record 12894.27
# Generation 41: Nuovo Record 12894.27
# Generation 58: Nuovo Record 12894.27
# Generation 60: Nuovo Record 12893.44
# Generation 65: Nuovo Record 12893.44
# Generation 80: Nuovo Record 12892.91
# Generation 88: Nuovo Record 12892.91
# Generation 116: Nuovo Record 12892.34
# Generation 161: Nuovo Record 12892.34
# Generation 170: Nuovo Record 12891.64
# Generation 190: Nuovo Record 12891.01
# Generation 196: Nuovo Record 12890.62
# GA cost: 12890.62 | Improvement: 0.05% | Time: 3.13s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 272495.07
# Temp: 1556.63 | Energia: 29614.76 | Record: 20995.17
# Temp: 1211.54 | Energia: 24977.63 | Record: 18470.59
# Temp: 942.96 | Energia: 26508.18 | Record: 17500.47
# Temp: 733.92 | Energia: 24272.08 | Record: 17500.47
# Temp: 571.22 | Energia: 18017.81 | Record: 15994.96
# Temp: 444.58 | Energia: 16506.40 | Record: 14355.74
# Temp: 346.03 | Energia: 18848.30 | Record: 14355.74
# Temp: 269.32 | Energia: 15608.71 | Record: 14355.74
# Temp: 209.61 | Energia: 15138.31 | Record: 14109.30
# Temp: 163.14 | Energia: 14166.60 | Record: 13192.85
# Temp: 126.98 | Energia: 14076.62 | Record: 13192.85
# Temp: 98.83 | Energia: 13925.49 | Record: 13192.85
# Temp: 76.92 | Energia: 13883.82 | Record: 12938.89
# Temp: 59.87 | Energia: 13260.04 | Record: 12925.10
# Temp: 46.60 | Energia: 13049.50 | Record: 12925.10
# Temp: 36.27 | Energia: 12969.83 | Record: 12895.35
# Temp: 28.23 | Energia: 12960.75 | Record: 12895.35
# Temp: 21.97 | Energia: 12971.93 | Record: 12895.35
# Temp: 17.10 | Energia: 12975.33 | Record: 12894.91
# Temp: 13.31 | Energia: 12896.10 | Record: 12894.91
# Temp: 10.36 | Energia: 12896.65 | Record: 12894.41
# Temp: 8.06 | Energia: 12943.47 | Record: 12894.41
# Temp: 6.27 | Energia: 12897.07 | Record: 12894.41
# Temp: 4.88 | Energia: 12897.07 | Record: 12894.41
# Temp: 3.80 | Energia: 12896.43 | Record: 12894.41
# Temp: 2.96 | Energia: 12895.18 | Record: 12894.41
# Temp: 2.30 | Energia: 12895.36 | Record: 12894.41
# Temp: 1.79 | Energia: 12893.79 | Record: 12893.79
# Temp: 1.39 | Energia: 12895.82 | Record: 12893.79
# Temp: 1.09 | Energia: 12894.97 | Record: 12893.79
# Temp: 0.84 | Energia: 12895.47 | Record: 12893.79
# Temp: 0.66 | Energia: 12895.22 | Record: 12893.79
# Temp: 0.51 | Energia: 12895.88 | Record: 12893.01
# Temp: 0.40 | Energia: 12894.98 | Record: 12893.01
# Temp: 0.31 | Energia: 12894.04 | Record: 12893.01
# Temp: 0.24 | Energia: 12894.04 | Record: 12893.01
# Temp: 0.19 | Energia: 12892.84 | Record: 12892.84
# Temp: 0.15 | Energia: 12891.83 | Record: 12891.83
# Temp: 0.11 | Energia: 12891.83 | Record: 12891.83
# SA cost: 12891.83 | Improvement: 0.04% | Time: 3.66s
#
# ================================================================================
# Esperimento 4
# n=50, density=0.2, alpha=1.0, beta=2.0
# ================================================================================
# Baseline cost: 2623731.82 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 5668738.23
# Generation 2: Nuovo Record 5334161.96
# Generation 3: Nuovo Record 4839604.19
# Generation 5: Nuovo Record 4831428.46
# Generation 6: Nuovo Record 4807152.83
# Generation 7: Nuovo Record 4507555.81
# Generation 12: Nuovo Record 4472839.29
# Generation 14: Nuovo Record 4461570.72
# Generation 17: Nuovo Record 4461570.72
# Generation 21: Nuovo Record 4460030.10
# Generation 23: Nuovo Record 4448525.65
# Generation 25: Nuovo Record 4440286.16
# Generation 27: Nuovo Record 4432840.96
# Generation 29: Nuovo Record 4432840.96
# Generation 31: Nuovo Record 4348654.09
# Generation 32: Nuovo Record 4347117.21
# Generation 34: Nuovo Record 4341208.89
# Generation 35: Nuovo Record 4339672.01
# Generation 36: Nuovo Record 4338059.77
# Generation 40: Nuovo Record 4338059.77
# Generation 43: Nuovo Record 4336522.89
# Generation 87: Nuovo Record 4334850.23
# Generation 88: Nuovo Record 4334850.23
# Generation 118: Nuovo Record 4280158.09
# Generation 124: Nuovo Record 4280158.09
# GA cost: 4280158.09 | Improvement: -63.13% | Time: 3.21s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 4101517004.40
# Temp: 1556.63 | Energia: 4732683.13 | Record: 4731878.57
# Temp: 1211.54 | Energia: 4660038.11 | Record: 4660038.11
# Temp: 942.96 | Energia: 4660038.11 | Record: 4660038.11
# Temp: 733.92 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 571.22 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 444.58 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 346.03 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 269.32 | Energia: 4654774.82 | Record: 4653970.25
# Temp: 209.61 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 163.14 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 126.98 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 98.83 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 76.92 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 59.87 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 46.60 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 36.27 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 28.23 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 21.97 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 17.10 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 13.31 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 10.36 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 8.06 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 6.27 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 4.88 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 3.80 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 2.96 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 2.30 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 1.79 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 1.39 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 1.09 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 0.84 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 0.66 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 0.51 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 0.40 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 0.31 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 0.24 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 0.19 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 0.15 | Energia: 4653970.25 | Record: 4653970.25
# Temp: 0.11 | Energia: 4653970.25 | Record: 4653970.25
# SA cost: 4653970.25 | Improvement: -77.38% | Time: 3.70s
#
# ================================================================================
# Esperimento 5
# n=50, density=0.4, alpha=0.5, beta=1.0
# ================================================================================
# Baseline cost: 4971.64 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 5140.23
# Generation 2: Nuovo Record 5128.67
# Generation 4: Nuovo Record 5056.84
# Generation 5: Nuovo Record 5056.84
# Generation 6: Nuovo Record 4991.64
# Generation 7: Nuovo Record 4984.58
# Generation 10: Nuovo Record 4974.52
# Generation 16: Nuovo Record 4971.60
# Generation 20: Nuovo Record 4969.47
# Generation 21: Nuovo Record 4969.47
# Generation 24: Nuovo Record 4969.47
# Generation 27: Nuovo Record 4968.95
# Generation 29: Nuovo Record 4968.69
# Generation 31: Nuovo Record 4968.61
# Generation 44: Nuovo Record 4967.69
# Generation 48: Nuovo Record 4967.69
# Generation 59: Nuovo Record 4966.90
# Generation 122: Nuovo Record 4966.37
# Generation 147: Nuovo Record 4965.77
# Generation 154: Nuovo Record 4965.77
# Generation 176: Nuovo Record 4965.29
# Generation 178: Nuovo Record 4965.25
# Generation 183: Nuovo Record 4964.59
# Generation 199: Nuovo Record 4964.59
# GA cost: 4964.59 | Improvement: 0.14% | Time: 3.18s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 81595.91
# Temp: 1556.63 | Energia: 11963.20 | Record: 8087.93
# Temp: 1211.54 | Energia: 12189.45 | Record: 8029.54
# Temp: 942.96 | Energia: 8062.79 | Record: 6707.32
# Temp: 733.92 | Energia: 10260.92 | Record: 6707.32
# Temp: 571.22 | Energia: 10682.09 | Record: 6707.32
# Temp: 444.58 | Energia: 8488.90 | Record: 6707.32
# Temp: 346.03 | Energia: 8437.48 | Record: 6486.99
# Temp: 269.32 | Energia: 7449.43 | Record: 6419.93
# Temp: 209.61 | Energia: 7049.76 | Record: 6419.93
# Temp: 163.14 | Energia: 6831.06 | Record: 5738.20
# Temp: 126.98 | Energia: 6202.46 | Record: 5734.23
# Temp: 98.83 | Energia: 5761.32 | Record: 5357.60
# Temp: 76.92 | Energia: 5727.57 | Record: 5357.60
# Temp: 59.87 | Energia: 5620.84 | Record: 5206.52
# Temp: 46.60 | Energia: 5060.71 | Record: 5044.59
# Temp: 36.27 | Energia: 5134.66 | Record: 5036.27
# Temp: 28.23 | Energia: 4994.33 | Record: 4981.15
# Temp: 21.97 | Energia: 5125.59 | Record: 4973.78
# Temp: 17.10 | Energia: 5158.66 | Record: 4970.70
# Temp: 13.31 | Energia: 4996.31 | Record: 4970.70
# Temp: 10.36 | Energia: 4998.98 | Record: 4970.70
# Temp: 8.06 | Energia: 4987.89 | Record: 4970.70
# Temp: 6.27 | Energia: 5014.29 | Record: 4970.70
# Temp: 4.88 | Energia: 4970.83 | Record: 4969.96
# Temp: 3.80 | Energia: 4978.43 | Record: 4969.96
# Temp: 2.96 | Energia: 4975.00 | Record: 4969.83
# Temp: 2.30 | Energia: 4971.25 | Record: 4969.83
# Temp: 1.79 | Energia: 4970.94 | Record: 4969.83
# Temp: 1.39 | Energia: 4971.47 | Record: 4969.03
# Temp: 1.09 | Energia: 4970.96 | Record: 4969.03
# Temp: 0.84 | Energia: 4970.81 | Record: 4967.80
# Temp: 0.66 | Energia: 4967.94 | Record: 4967.80
# Temp: 0.51 | Energia: 4967.86 | Record: 4967.12
# Temp: 0.40 | Energia: 4970.51 | Record: 4966.99
# Temp: 0.31 | Energia: 4970.96 | Record: 4966.99
# Temp: 0.24 | Energia: 4968.35 | Record: 4966.99
# Temp: 0.19 | Energia: 4968.62 | Record: 4966.99
# Temp: 0.15 | Energia: 4967.86 | Record: 4966.99
# Temp: 0.11 | Energia: 4967.09 | Record: 4966.99
# SA cost: 4966.99 | Improvement: 0.09% | Time: 3.73s
#
# ================================================================================
# Esperimento 6
# n=50, density=0.4, alpha=0.5, beta=2.0
# ================================================================================
# Baseline cost: 486260.01 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 775478.19
# Generation 2: Nuovo Record 693576.14
# Generation 5: Nuovo Record 692141.59
# Generation 7: Nuovo Record 673533.60
# Generation 8: Nuovo Record 667836.42
# Generation 9: Nuovo Record 667088.76
# Generation 11: Nuovo Record 666620.78
# Generation 12: Nuovo Record 660647.51
# Generation 17: Nuovo Record 660647.51
# Generation 21: Nuovo Record 656563.25
# Generation 23: Nuovo Record 655456.99
# Generation 24: Nuovo Record 652292.43
# Generation 27: Nuovo Record 651631.47
# Generation 30: Nuovo Record 648791.47
# Generation 31: Nuovo Record 644841.73
# Generation 36: Nuovo Record 644841.73
# Generation 40: Nuovo Record 644841.73
# Generation 153: Nuovo Record 633363.52
# Generation 156: Nuovo Record 633363.52
# Generation 175: Nuovo Record 632927.31
# Generation 176: Nuovo Record 632760.13
# Generation 185: Nuovo Record 632760.13
# Generation 187: Nuovo Record 630880.11
# Generation 188: Nuovo Record 628605.15
# GA cost: 628605.15 | Improvement: -29.27% | Time: 3.19s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 340624929.00
# Temp: 1556.63 | Energia: 685103.39 | Record: 677982.55
# Temp: 1211.54 | Energia: 686084.67 | Record: 677982.55
# Temp: 942.96 | Energia: 678855.83 | Record: 677982.55
# Temp: 733.92 | Energia: 677982.55 | Record: 677379.16
# Temp: 571.22 | Energia: 679366.98 | Record: 677379.16
# Temp: 444.58 | Energia: 677982.55 | Record: 677379.16
# Temp: 346.03 | Energia: 677379.16 | Record: 677379.16
# Temp: 269.32 | Energia: 675020.70 | Record: 675020.70
# Temp: 209.61 | Energia: 675020.70 | Record: 675020.70
# Temp: 163.14 | Energia: 675020.70 | Record: 675020.70
# Temp: 126.98 | Energia: 675020.70 | Record: 675020.70
# Temp: 98.83 | Energia: 675020.70 | Record: 675020.70
# Temp: 76.92 | Energia: 675020.70 | Record: 675020.70
# Temp: 59.87 | Energia: 675020.70 | Record: 675020.70
# Temp: 46.60 | Energia: 675020.70 | Record: 675020.70
# Temp: 36.27 | Energia: 675020.70 | Record: 675020.70
# Temp: 28.23 | Energia: 675020.70 | Record: 675020.70
# Temp: 21.97 | Energia: 675020.70 | Record: 675020.70
# Temp: 17.10 | Energia: 675020.70 | Record: 675020.70
# Temp: 13.31 | Energia: 675020.70 | Record: 675020.70
# Temp: 10.36 | Energia: 675020.70 | Record: 675020.70
# Temp: 8.06 | Energia: 675020.70 | Record: 675020.70
# Temp: 6.27 | Energia: 675020.70 | Record: 675020.70
# Temp: 4.88 | Energia: 675020.70 | Record: 675020.70
# Temp: 3.80 | Energia: 675020.70 | Record: 675020.70
# Temp: 2.96 | Energia: 675020.70 | Record: 675020.70
# Temp: 2.30 | Energia: 675020.70 | Record: 675020.70
# Temp: 1.79 | Energia: 675020.70 | Record: 675020.70
# Temp: 1.39 | Energia: 675020.70 | Record: 675020.70
# Temp: 1.09 | Energia: 675020.70 | Record: 675020.70
# Temp: 0.84 | Energia: 675020.70 | Record: 675020.70
# Temp: 0.66 | Energia: 675020.70 | Record: 675020.70
# Temp: 0.51 | Energia: 675020.70 | Record: 675020.70
# Temp: 0.40 | Energia: 675020.70 | Record: 675020.70
# Temp: 0.31 | Energia: 675020.70 | Record: 675020.70
# Temp: 0.24 | Energia: 675020.70 | Record: 675020.70
# Temp: 0.19 | Energia: 675020.70 | Record: 675020.70
# Temp: 0.15 | Energia: 675020.70 | Record: 675020.70
# Temp: 0.11 | Energia: 675020.70 | Record: 675020.70
# SA cost: 675020.70 | Improvement: -38.82% | Time: 3.74s
#
# ================================================================================
# Esperimento 7
# n=50, density=0.4, alpha=1.0, beta=1.0
# ================================================================================
# Baseline cost: 9902.62 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 10579.55
# Generation 1: Nuovo Record 10506.87
# Generation 2: Nuovo Record 10487.38
# Generation 3: Nuovo Record 10415.76
# Generation 4: Nuovo Record 10151.35
# Generation 5: Nuovo Record 10114.30
# Generation 6: Nuovo Record 10043.19
# Generation 7: Nuovo Record 10038.52
# Generation 8: Nuovo Record 10016.25
# Generation 10: Nuovo Record 9992.50
# Generation 11: Nuovo Record 9987.71
# Generation 14: Nuovo Record 9918.57
# Generation 18: Nuovo Record 9902.62
# Generation 20: Nuovo Record 9902.62
# Generation 23: Nuovo Record 9902.62
# Generation 28: Nuovo Record 9902.10
# Generation 31: Nuovo Record 9902.10
# Generation 35: Nuovo Record 9902.10
# Generation 38: Nuovo Record 9901.77
# Generation 39: Nuovo Record 9901.77
# Generation 40: Nuovo Record 9900.85
# Generation 43: Nuovo Record 9900.59
# Generation 60: Nuovo Record 9899.93
# Generation 78: Nuovo Record 9899.93
# Generation 83: Nuovo Record 9899.15
# Generation 95: Nuovo Record 9898.25
# Generation 111: Nuovo Record 9898.25
# Generation 117: Nuovo Record 9898.25
# Generation 124: Nuovo Record 9897.97
# Generation 127: Nuovo Record 9897.71
# Generation 130: Nuovo Record 9896.84
# Generation 134: Nuovo Record 9896.84
# Generation 147: Nuovo Record 9896.09
# Generation 176: Nuovo Record 9896.09
# GA cost: 9896.09 | Improvement: 0.07% | Time: 3.06s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 163178.95
# Temp: 1556.63 | Energia: 16928.94 | Record: 16675.26
# Temp: 1211.54 | Energia: 18712.81 | Record: 14560.78
# Temp: 942.96 | Energia: 19338.89 | Record: 14502.94
# Temp: 733.92 | Energia: 17152.69 | Record: 14502.94
# Temp: 571.22 | Energia: 14826.17 | Record: 12250.61
# Temp: 444.58 | Energia: 12266.61 | Record: 12173.20
# Temp: 346.03 | Energia: 15402.90 | Record: 11575.23
# Temp: 269.32 | Energia: 12210.41 | Record: 11431.18
# Temp: 209.61 | Energia: 11678.57 | Record: 11000.72
# Temp: 163.14 | Energia: 11143.97 | Record: 10596.22
# Temp: 126.98 | Energia: 11362.91 | Record: 10544.34
# Temp: 98.83 | Energia: 10809.47 | Record: 10054.08
# Temp: 76.92 | Energia: 10483.61 | Record: 10009.14
# Temp: 59.87 | Energia: 10347.50 | Record: 10007.86
# Temp: 46.60 | Energia: 10052.56 | Record: 9911.32
# Temp: 36.27 | Energia: 10148.48 | Record: 9911.32
# Temp: 28.23 | Energia: 10034.00 | Record: 9910.28
# Temp: 21.97 | Energia: 9971.02 | Record: 9910.28
# Temp: 17.10 | Energia: 9940.38 | Record: 9902.36
# Temp: 13.31 | Energia: 9902.62 | Record: 9902.25
# Temp: 10.36 | Energia: 9902.62 | Record: 9901.54
# Temp: 8.06 | Energia: 9901.22 | Record: 9900.39
# Temp: 6.27 | Energia: 9901.87 | Record: 9900.39
# Temp: 4.88 | Energia: 9906.13 | Record: 9900.39
# Temp: 3.80 | Energia: 9901.71 | Record: 9900.14
# Temp: 2.96 | Energia: 9901.81 | Record: 9900.14
# Temp: 2.30 | Energia: 9902.62 | Record: 9900.14
# Temp: 1.79 | Energia: 9901.81 | Record: 9900.14
# Temp: 1.39 | Energia: 9901.18 | Record: 9900.14
# Temp: 1.09 | Energia: 9900.85 | Record: 9900.14
# Temp: 0.84 | Energia: 9902.09 | Record: 9900.10
# Temp: 0.66 | Energia: 9901.87 | Record: 9900.10
# Temp: 0.51 | Energia: 9902.36 | Record: 9900.10
# Temp: 0.40 | Energia: 9900.03 | Record: 9900.03
# Temp: 0.31 | Energia: 9900.38 | Record: 9900.03
# Temp: 0.24 | Energia: 9900.17 | Record: 9900.03
# Temp: 0.19 | Energia: 9899.45 | Record: 9899.45
# Temp: 0.15 | Energia: 9899.13 | Record: 9899.13
# Temp: 0.11 | Energia: 9898.64 | Record: 9898.38
# SA cost: 9898.38 | Improvement: 0.04% | Time: 3.74s
#
# ================================================================================
# Esperimento 8
# n=50, density=0.4, alpha=1.0, beta=2.0
# ================================================================================
# Baseline cost: 1944918.09 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 3221569.72
# Generation 1: Nuovo Record 2874338.69
# Generation 3: Nuovo Record 2866418.04
# Generation 4: Nuovo Record 2844718.79
# Generation 6: Nuovo Record 2789096.94
# Generation 7: Nuovo Record 2775530.79
# Generation 9: Nuovo Record 2764357.67
# Generation 10: Nuovo Record 2747347.24
# Generation 13: Nuovo Record 2733406.18
# Generation 14: Nuovo Record 2722790.33
# Generation 15: Nuovo Record 2694717.71
# Generation 17: Nuovo Record 2691527.77
# Generation 18: Nuovo Record 2678746.77
# Generation 20: Nuovo Record 2677488.64
# Generation 21: Nuovo Record 2671975.16
# Generation 26: Nuovo Record 2666154.66
# Generation 27: Nuovo Record 2666154.66
# Generation 29: Nuovo Record 2666006.12
# Generation 31: Nuovo Record 2666006.12
# Generation 32: Nuovo Record 2648405.87
# Generation 37: Nuovo Record 2645993.71
# Generation 45: Nuovo Record 2645993.71
# Generation 71: Nuovo Record 2636091.40
# Generation 72: Nuovo Record 2614495.84
# Generation 96: Nuovo Record 2614495.84
# Generation 126: Nuovo Record 2596722.57
# Generation 128: Nuovo Record 2596565.95
# Generation 129: Nuovo Record 2557114.20
# Generation 152: Nuovo Record 2557114.20
# Generation 173: Nuovo Record 2516756.70
# Generation 176: Nuovo Record 2508065.01
# Generation 190: Nuovo Record 2501861.02
# Generation 199: Nuovo Record 2501861.02
# GA cost: 2501861.02 | Improvement: -28.64% | Time: 3.10s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy):

# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 259746.07
# Temp: 1556.63 | Energia: 29905.52 | Record: 22061.46
# Temp: 1211.54 | Energia: 32465.86 | Record: 21689.00
# Temp: 942.96 | Energia: 27212.29 | Record: 21041.93
# Temp: 733.92 | Energia: 20508.78 | Record: 20091.28
# Temp: 571.22 | Energia: 26979.98 | Record: 19624.94
# Temp: 444.58 | Energia: 22881.56 | Record: 19463.11
# Temp: 346.03 | Energia: 20167.50 | Record: 17149.45
# Temp: 269.32 | Energia: 16913.42 | Record: 16473.50
# Temp: 209.61 | Energia: 17878.40 | Record: 15258.45
# Temp: 163.14 | Energia: 16943.06 | Record: 14716.48
# Temp: 126.98 | Energia: 15393.41 | Record: 14119.54
# Temp: 98.83 | Energia: 14696.29 | Record: 13962.02
# Temp: 76.92 | Energia: 14591.94 | Record: 13860.87
# Temp: 59.87 | Energia: 14029.62 | Record: 13378.69
# Temp: 46.60 | Energia: 13523.82 | Record: 13312.75
# Temp: 36.27 | Energia: 13338.59 | Record: 12956.28
# Temp: 28.23 | Energia: 12784.20 | Record: 12784.20
# Temp: 21.97 | Energia: 12929.91 | Record: 12784.20
# Temp: 17.10 | Energia: 12785.09 | Record: 12735.18
# Temp: 13.31 | Energia: 12837.59 | Record: 12694.65
# Temp: 10.36 | Energia: 12807.99 | Record: 12694.65
# Temp: 8.06 | Energia: 12747.59 | Record: 12694.65
# Temp: 6.27 | Energia: 12727.04 | Record: 12694.65
# Temp: 4.88 | Energia: 12702.27 | Record: 12694.65
# Temp: 3.80 | Energia: 12685.67 | Record: 12684.56
# Temp: 2.96 | Energia: 12694.82 | Record: 12684.56
# Temp: 2.30 | Energia: 12686.48 | Record: 12684.02
# Temp: 1.79 | Energia: 12683.72 | Record: 12681.65
# Temp: 1.39 | Energia: 12691.20 | Record: 12681.37
# Temp: 1.09 | Energia: 12687.03 | Record: 12681.37
# Temp: 0.84 | Energia: 12683.98 | Record: 12681.37
# Temp: 0.66 | Energia: 12684.65 | Record: 12681.37
# Temp: 0.51 | Energia: 12683.02 | Record: 12681.37
# Temp: 0.40 | Energia: 12684.82 | Record: 12681.37
# Temp: 0.31 | Energia: 12682.30 | Record: 12681.37
# Temp: 0.24 | Energia: 12681.89 | Record: 12681.37
# Temp: 0.19 | Energia: 12679.95 | Record: 12679.95
# Temp: 0.15 | Energia: 12678.18 | Record: 12678.18
# Temp: 0.11 | Energia: 12678.18 | Record: 12678.18
# SA cost: 12677.14 | Improvement: 0.08% | Time: 7.08s
#
# ================================================================================
# Esperimento 10
# n=100, density=0.2, alpha=0.5, beta=2.0
# ================================================================================
# Baseline cost: 1333681.11 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 3941888.64
# Generation 1: Nuovo Record 3596155.86
# Generation 3: Nuovo Record 3468264.12
# Generation 4: Nuovo Record 3284923.75
# Generation 6: Nuovo Record 3036454.83
# Generation 9: Nuovo Record 2838026.35
# Generation 14: Nuovo Record 2771503.40
# Generation 15: Nuovo Record 2746143.65
# Generation 18: Nuovo Record 2714636.21
# Generation 19: Nuovo Record 2686109.72
# Generation 25: Nuovo Record 2652507.49
# Temp: 269.32 | Energia: 9371839.72 | Record: 9371839.72
# Temp: 209.61 | Energia: 9371814.24 | Record: 9371814.24
# Temp: 163.14 | Energia: 9371814.24 | Record: 9371814.24
# Temp: 126.98 | Energia: 9371814.24 | Record: 9371814.24
# Temp: 98.83 | Energia: 9371839.72 | Record: 9371814.24
# Temp: 76.92 | Energia: 9371839.72 | Record: 9371814.24
# ...
# Generation 27: Nuovo Record 1418230.49
# Generation 29: Nuovo Record 1416050.88
# Generation 30: Nuovo Record 1416050.88
# Generation 31: Nuovo Record 1409197.75
# Generation 32: Nuovo Record 1403117.23
# Generation 33: Nuovo Record 1402430.13
# Generation 34: Nuovo Record 1396672.73
# Generation 35: Nuovo Record 1393687.87
# Generation 40: Nuovo Record 1388161.11
# Generation 41: Nuovo Record 1386189.50
# Generation 45: Nuovo Record 1385489.85
# Generation 46: Nuovo Record 1383879.65
# Generation 48: Nuovo Record 1375807.79
# Generation 49: Nuovo Record 1369618.03
# Generation 50: Nuovo Record 1369562.41
# Generation 52: Nuovo Record 1365297.46
# Generation 54: Nuovo Record 1364868.38
# Generation 55: Nuovo Record 1364868.38
# Generation 56: Nuovo Record 1363717.32
# Generation 57: Nuovo Record 1359876.91
# Generation 59: Nuovo Record 1359396.76
# Generation 60: Nuovo Record 1357204.41
# Generation 61: Nuovo Record 1353540.56
# Generation 62: Nuovo Record 1351783.85
# Generation 63: Nuovo Record 1349751.73
# Generation 64: Nuovo Record 1347377.82
# Generation 66: Nuovo Record 1347113.82
# Generation 67: Nuovo Record 1345345.69
# Generation 68: Nuovo Record 1345081.69
# Generation 78: Nuovo Record 1344809.32
# Generation 79: Nuovo Record 1343111.34
# Generation 83: Nuovo Record 1336652.43
# Generation 86: Nuovo Record 1334682.08
# Generation 88: Nuovo Record 1331364.76
# Generation 93: Nuovo Record 1325676.71
# Generation 101: Nuovo Record 1325676.71
# Generation 105: Nuovo Record 1325553.50
# Generation 107: Nuovo Record 1322126.46
# Generation 109: Nuovo Record 1322003.25
# Generation 112: Nuovo Record 1322003.25
# Generation 134: Nuovo Record 1322003.25
# Generation 155: Nuovo Record 1322003.25
# Generation 156: Nuovo Record 1321511.60
# Generation 159: Nuovo Record 1321511.60
# Generation 160: Nuovo Record 1319983.00
# Generation 163: Nuovo Record 1319983.00
# Generation 176: Nuovo Record 1319983.00
# Generation 178: Nuovo Record 1317159.11
# Generation 182: Nuovo Record 1307713.60
# Generation 195: Nuovo Record 1307713.60
# Generation 196: Nuovo Record 1305956.81
# GA cost: 1305956.81 | Improvement: -8.93% | Time: 6.29s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 1451585552.06
# Temp: 1556.63 | Energia: 1497806.78 | Record: 1492466.25
# Temp: 1211.54 | Energia: 1449031.41 | Record: 1449031.41
# Temp: 942.96 | Energia: 1406801.59 | Record: 1405542.72
# Temp: 733.92 | Energia: 1403956.17 | Record: 1403351.97
# Temp: 571.22 | Energia: 1380153.40 | Record: 1379609.24
# Temp: 444.58 | Energia: 1378868.40 | Record: 1378743.71
# Temp: 346.03 | Energia: 1371795.95 | Record: 1371280.64
# Temp: 269.32 | Energia: 1364528.58 | Record: 1364528.58
# Temp: 209.61 | Energia: 1363034.97 | Record: 1363034.97
# Temp: 163.14 | Energia: 1359614.10 | Record: 1359614.10
# Temp: 126.98 | Energia: 1359614.10 | Record: 1359598.22
# Temp: 98.83 | Energia: 1359298.27 | Record: 1359069.94
# Temp: 76.92 | Energia: 1359054.06 | Record: 1359054.06
# Temp: 59.87 | Energia: 1359054.06 | Record: 1359054.06
# Temp: 46.60 | Energia: 1359054.06 | Record: 1359054.06
# Temp: 36.27 | Energia: 1359054.06 | Record: 1359054.06
# Temp: 28.23 | Energia: 1359054.06 | Record: 1359054.06
# Temp: 21.97 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 17.10 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 13.31 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 10.36 | Energia: 1358751.16 | Record: 1358735.27
# Temp: 8.06 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 6.27 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 4.88 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 3.80 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 2.96 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 2.30 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 1.79 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 1.39 | Energia: 1358735.27 | Record: 1358735.27
# Temp: 1.09 | Energia: 1358456.85 | Record: 1358456.85
# Temp: 0.84 | Energia: 1358456.85 | Record: 1358456.85
# Temp: 0.66 | Energia: 1358456.85 | Record: 1358456.85
# Temp: 0.51 | Energia: 1358456.85 | Record: 1358456.85
# Temp: 0.40 | Energia: 1358456.85 | Record: 1358456.85
# Temp: 0.31 | Energia: 1358456.85 | Record: 1358456.85
# Temp: 0.24 | Energia: 1358456.85 | Record: 1358456.85
# Temp: 0.19 | Energia: 1358456.85 | Record: 1358456.85
# Temp: 0.15 | Energia: 1358456.85 | Record: 1358456.85
# Temp: 0.11 | Energia: 1358456.85 | Record: 1358456.85
# SA cost: 1358456.85 | Improvement: -13.31% | Time: 7.31s
#
# ================================================================================
# Esperimento 15
# n=100, density=0.4, alpha=1.0, beta=1.0
# ================================================================================
# Baseline cost: 19219.61 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 20841.55
# Generation 1: Nuovo Record 20596.82
# Generation 2: Nuovo Record 20512.82
# Generation 3: Nuovo Record 20087.83
# Generation 6: Nuovo Record 20072.74
# Generation 8: Nuovo Record 19986.49
# Generation 9: Nuovo Record 19760.01
# Generation 12: Nuovo Record 19602.50
# Generation 13: Nuovo Record 19536.20
# Generation 16: Nuovo Record 19465.19
# Generation 18: Nuovo Record 19442.09
# Generation 20: Nuovo Record 19424.36
# Generation 21: Nuovo Record 19353.36
# Generation 22: Nuovo Record 19346.30
# Generation 24: Nuovo Record 19293.54
# Generation 26: Nuovo Record 19286.06
# Generation 29: Nuovo Record 19266.85
# Generation 31: Nuovo Record 19266.85
# Generation 32: Nuovo Record 19259.75
# Generation 34: Nuovo Record 19255.97
# Generation 36: Nuovo Record 19248.88
# Generation 41: Nuovo Record 19240.57
# Generation 42: Nuovo Record 19219.02
# Generation 49: Nuovo Record 19218.53
# Generation 52: Nuovo Record 19218.53
# Generation 64: Nuovo Record 19218.53
# Generation 70: Nuovo Record 19218.52
# Generation 71: Nuovo Record 19217.91
# Generation 72: Nuovo Record 19217.89
# Generation 73: Nuovo Record 19217.89
# Generation 89: Nuovo Record 19217.89
# Generation 119: Nuovo Record 19217.89
# Generation 127: Nuovo Record 19217.89
# Generation 139: Nuovo Record 19217.15
# Generation 156: Nuovo Record 19217.15
# Generation 159: Nuovo Record 19216.39
# GA cost: 19216.39 | Improvement: 0.02% | Time: 6.28s
# --- Inizio Thermodynamic Greedy Search ---
# Energia Iniziale (Greedy): 411239.30
# Temp: 1556.63 | Energia: 43504.39 | Record: 32444.97
# Temp: 1211.54 | Energia: 49443.42 | Record: 30919.59
# Temp: 942.96 | Energia: 32538.87 | Record: 27123.16
# Temp: 733.92 | Energia: 31887.53 | Record: 27123.16
# Temp: 571.22 | Energia: 27686.06 | Record: 25250.92
# Temp: 444.58 | Energia: 29232.03 | Record: 25250.92
# Temp: 346.03 | Energia: 27068.35 | Record: 24272.25
# Temp: 269.32 | Energia: 22905.73 | Record: 22704.36
# Temp: 209.61 | Energia: 23910.55 | Record: 22704.36
# Temp: 163.14 | Energia: 22778.02 | Record: 21594.85
# Temp: 126.98 | Energia: 22488.49 | Record: 21139.27
# Temp: 98.83 | Energia: 20448.37 | Record: 20334.57
# Temp: 76.92 | Energia: 20363.97 | Record: 19974.34
# Temp: 59.87 | Energia: 20293.21 | Record: 19852.15
# Temp: 46.60 | Energia: 19638.24 | Record: 19565.64
# Temp: 36.27 | Energia: 19377.71 | Record: 19348.60
# Temp: 28.23 | Energia: 19414.28 | Record: 19313.10
# Temp: 21.97 | Energia: 19371.07 | Record: 19263.17
# Temp: 17.10 | Energia: 19394.39 | Record: 19263.17
# Temp: 13.31 | Energia: 19322.32 | Record: 19263.17
# Temp: 10.36 | Energia: 19246.72 | Record: 19232.04
# Temp: 8.06 | Energia: 19242.20 | Record: 19232.04
# Temp: 6.27 | Energia: 19270.08 | Record: 19228.57
# Temp: 4.88 | Energia: 19248.26 | Record: 19225.71
# Temp: 3.80 | Energia: 19227.07 | Record: 19225.71
# Temp: 2.96 | Energia: 19219.61 | Record: 19219.57
# Temp: 2.30 | Energia: 19221.87 | Record: 19218.88
# Temp: 1.79 | Energia: 19218.27 | Record: 19218.27
# Temp: 1.39 | Energia: 19218.90 | Record: 19218.16
# Temp: 1.09 | Energia: 19219.57 | Record: 19217.84
# Temp: 0.84 | Energia: 19219.57 | Record: 19217.84
# Temp: 0.66 | Energia: 19218.15 | Record: 19217.84
# Temp: 0.51 | Energia: 19219.14 | Record: 19216.97
# Temp: 0.40 | Energia: 19219.11 | Record: 19216.97
# Temp: 0.31 | Energia: 19219.25 | Record: 19216.97
# Temp: 0.24 | Energia: 19217.94 | Record: 19216.97
# Temp: 0.19 | Energia: 19214.06 | Record: 19214.06
# Temp: 0.15 | Energia: 19213.71 | Record: 19213.68
# Temp: 0.11 | Energia: 19213.68 | Record: 19213.68
# SA cost: 19213.68 | Improvement: 0.03% | Time: 7.20s
#
# ================================================================================
# Esperimento 16
# n=100, density=0.4, alpha=1.0, beta=2.0
# ================================================================================
# Baseline cost: 4795161.99 (0.00s)
# Pre-calcolo delle distanze in corso...
# Pre-calcolo delle distanze completato.
# Inizio Genetic Algorithm con population_size=50, generations=200, mutation_rate=0.1
# Generation 0: Nuovo Record 6770976.74
# Generation 1: Nuovo Record 6628179.48
# Generation 3: Nuovo Record 6407976.34
# Generation 4: Nuovo Record 6357083.39
# Generation 5: Nuovo Record 6274168.57
# Generation 7: Nuovo Record 6244356.00
# Generation 8: Nuovo Record 6123929.03
# Generation 9: Nuovo Record 6088754.70
# Generation 10: Nuovo Record 5943729.03
# Generation 12: Nuovo Record 5920258.26
# Generation 13: Nuovo Record 5906268.78
# Generation 14: Nuovo Record 5886766.10
# Generation 16: Nuovo Record 5874427.40
# Generation 17: Nuovo Record 5855479.22
# Generation 18: Nuovo Record 5837403.31
# Generation 19: Nuovo Record 5835880.03
# Generation 20: Nuovo Record 5769067.74
| Energia: 5387526.36 | Record: 5387526.36
# Temp: 8.06 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 6.27 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 4.88 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 3.80 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 2.96 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 2.30 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 1.79 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 1.39 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 1.09 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 0.84 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 0.66 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 0.51 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 0.40 | Energia: 5387526.36 | Record: 5387526.36
# Temp: 0.31 | Energia: 5366892.37 | Record: 5366892.37
# Temp: 0.24 | Energia: 5366892.37 | Record: 5366892.37
# Temp: 0.19 | Energia: 5366892.37 | Record: 5366892.37
# Temp: 0.15 | Energia: 5366892.37 | Record: 5366892.37
# Temp: 0.11 | Energia: 5366892.37 | Record: 5366892.37
# SA cost: 5366892.37 | Improvement: -11.92% | Time: 7.30s
#
# ================================================================================
# RISULTATI FINALI
# ================================================================================
#       n  density  alpha  beta  baseline_cost  baseline_time       ga_cost  \
# 0    50      0.2    0.5   1.0   6.475521e+03       0.000703  6.468575e+03
# 1    50      0.2    0.5   2.0   6.559732e+05       0.000559  1.063612e+06
# 2    50      0.2    1.0   1.0   1.289733e+04       0.000550  1.289062e+04
# 3    50      0.2    1.0   2.0   2.623732e+06       0.000553  4.280158e+06
# 4    50      0.4    0.5   1.0   4.971638e+03       0.000561  4.964590e+03
# 5    50      0.4    0.5   2.0   4.862600e+05       0.000574  6.286052e+05
# 6    50      0.4    1.0   1.0   9.902623e+03       0.000611  9.896089e+03
# 7    50      0.4    1.0   2.0   1.944918e+06       0.000581  2.501861e+06
# 8   100      0.2    0.5   1.0   1.268695e+04       0.001501  1.268713e+04
# 9   100      0.2    0.5   2.0   1.333681e+06       0.001391  2.269363e+06
# 10  100      0.2    1.0   1.0   2.526641e+04       0.001442  2.526385e+04
# 11  100      0.2    1.0   2.0   5.334402e+06       0.001379  8.788832e+06
# 12  100      0.4    0.5   1.0   9.649212e+03       0.001499  9.646761e+03
# 13  100      0.4    0.5   2.0   1.198850e+06       0.001520  1.305957e+06
# 14  100      0.4    1.0   1.0   1.921961e+04       0.001479  1.921639e+04
# 15  100      0.4    1.0   2.0   4.795162e+06       0.001524  5.207181e+06
#
#      ga_time  ga_improvement_%       sa_cost   sa_time  sa_improvement_%
# 0   3.222782          0.107274  6.468625e+03  3.724172          0.106499
# 1   3.115460        -62.142526  1.103696e+06  3.577145        -68.253149
# 2   3.134264          0.052035  1.289183e+04  3.657602          0.042600
# 3   3.214028        -63.132453  4.653970e+06  3.700068        -77.379800
# 4   3.175072          0.141778  4.966993e+03  3.727673          0.093431
# 5   3.185879        -29.273462  6.750207e+05  3.735686        -38.818880
# 6   3.060998          0.065983  9.898375e+03  3.737221          0.042897
# 7   3.104813        -28.635804  2.701304e+06  3.738883        -38.890374
# 8   6.312163         -0.001369  1.267714e+04  7.078842          0.077366
# 9   6.290810        -70.157831  2.252628e+06  7.535126        -68.903021
# 10  6.398565          0.010112  2.525848e+04  7.413519          0.031381
# 11  6.343745        -64.757593  9.354575e+06  7.353489        -75.363136
# 12  6.412788          0.025399  9.646553e+03  7.235848          0.027555
# 13  6.287933         -8.934165  1.358457e+06  7.307427        -13.313366
# 14  6.282519          0.016715  1.921368e+04  7.199054          0.030824
# 15  6.339074         -8.592383  5.366892e+06  7.299624        -11.923067
